# %%
#Imports
import pandas as pd
import functions as func
import yaml
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

db_locations = func.import_yaml()

#load df
df_1 = pd.read_csv(db_locations['data_clean']['user_data'])
df_2 = pd.read_csv(db_locations['data_clean']['user_logs'])

# %%
df_1
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#           bal  calls_6_mnth  logons_6_mnth Variation
# 0        45.0           6.0            9.0      Test
# 1       111.0           6.0            9.0   Control
# 2        52.0           6.0            9.0      Test
# 3        67.0           3.0            6.0      Test
# 4       104.0           0.0            3.0   Control
# ...       ...           ...            ...       ...
# 50483   372.0           6.0            9.0      Test
# 50484  4280.0           6.0            9.0   Control
# 50485    45.0           2.0            5.0      Test
# 50486    45.0           1.0            4.0      Test
# 50487   209.0           0.0            3.0      Test
#
# [50488 rows x 10 columns]

# %%
df_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         5867343  100011869_84756704576  406596333_52561114200_989487
# 1         5867343  100011869_84756704576  406596333_52561114200_989487
# 2         5867343  100011869_84756704576  406596333_52561114200_989487
# 3         5867343  100011869_84756704576  406596333_52561114200_989487
# 4         5867343  100011869_84756704576  406596333_52561114200_989487
# ...           ...                    ...                           ...
# 744636    7042750  999998529_89539814462  583327415_19513940564_488564
# 744637    7042750  999998529_89539814462  583327415_19513940564_488564
# 744638    7042750  999998529_89539814462  583327415_19513940564_488564
# 744639    7042750  999998529_89539814462  583327415_19513940564_488564
# 744640    7042750  999998529_89539814462  583327415_19513940564_488564
#
#        process_step            date_time            prev_time  \
# 0             start  2017-06-05 02:47:42                  NaN
# 1            step_1  2017-06-05 02:47:47  2017-06-05 02:47:42
# 2            step_2  2017-06-05 02:48:03  2017-06-05 02:47:47
# 3            step_3  2017-06-05 02:50:18  2017-06-05 02:48:03
# 4             start  2017-06-05 02:51:11  2017-06-05 02:50:18
# ...             ...                  ...                  ...
# 744636       step_2  2017-04-12 11:55:05  2017-04-12 11:52:11
# 744637       step_3  2017-04-12 11:55:13  2017-04-12 11:55:05
# 744638      confirm  2017-04-12 12:04:47  2017-04-12 11:55:13
# 744639        start  2017-04-12 12:09:29  2017-04-12 12:04:47
# 744640       step_1  2017-04-12 12:09:47  2017-04-12 12:09:29
#
#               time_diff  time_diff_seconds  error
# 0                   NaN                NaN      0
# 1       0 days 00:00:05                5.0      0
# 2       0 days 00:00:16               16.0      0
# 3       0 days 00:02:15              135.0      0
# 4       0 days 00:00:53               53.0      0
# ...                 ...                ...    ...
# 744636  0 days 00:02:54              174.0      1
# 744637  0 days 00:00:08                8.0      0
# 744638  0 days 00:09:34              574.0      0
# 744639  0 days 00:04:42              282.0      0
# 744640  0 days 00:00:18               18.0      0
#
# [744641 rows x 9 columns]

# %%
#checking errors by users 
df_2['error'].value_counts()
# Out:
# error
# 0    722722
# 1     21919
# Name: count, dtype: int64

# %%
df_2['error'].value_counts(normalize=True)
# Out:
# error
# 0    0.970564
# 1    0.029436
# Name: proportion, dtype: float64

# %%
proportion_table = df_2['error'].value_counts(normalize=True)
plt.pie(proportion_table.values, labels = proportion_table.index)
plt.show()

# %%
grouped_df = df_2.groupby('client_id')['error'].sum().reset_index()
grouped_df
# Out:
#         client_id  error
# 0             169      0
# 1             336      0
# 2             546      0
# 3             555      0
# 4             647      0
# ...           ...    ...
# 120152    9999729      0
# 120153    9999768      2
# 120154    9999832      0
# 120155    9999839      0
# 120156    9999875      0
#
# [120157 rows x 2 columns]

# %%
# checking if error are related to any other columns
merged_df = pd.merge(df_1, grouped_df, on='client_id', how='inner')
merged_df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#           bal  calls_6_mnth  logons_6_mnth Variation  error
# 0        45.0           6.0            9.0      Test      0
# 1       111.0           6.0            9.0   Control      0
# 2        52.0           6.0            9.0      Test      0
# 3        67.0           3.0            6.0      Test      0
# 4       104.0           0.0            3.0   Control      0
# ...       ...           ...            ...       ...    ...
# 50483   372.0           6.0            9.0      Test      0
# 50484  4280.0           6.0            9.0   Control      0
# 50485    45.0           2.0            5.0      Test      0
# 50486    45.0           1.0            4.0      Test      0
# 50487   209.0           0.0            3.0      Test      0
#
# [50488 rows x 11 columns]

# %%
correlation_matrix = merged_df.select_dtypes("number").corr()

# Setting up the matplotlib figure with an appropriate size
plt.figure(figsize=(18, 15))

# Drawing the heatmap for the numerical columns
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap for Selected Numerical Variables")
plt.show()

# %%
crosstab_result = pd.crosstab(merged_df['error'], merged_df['Variation'])
crosstab_result
# Out:
# Variation  Control   Test
# error
# 0            20824  23739
# 1             1869   1879
# 2              620    932
# 3              142    180
# 4               44    125
# 5               20     48
# 6                5     16
# 7                0     22
# 8                1      7
# 9                0      3
# 10               1      2
# 11               1      3
# 12               0      2
# 14               0      1
# 17               0      1
# 22               0      1

# %%
crosstab_result.plot(kind="bar", stacked=True);

# %%
crosstab_result = pd.crosstab(merged_df['error'], merged_df['gendr'])
crosstab_result
# Out:
# gendr      F      M      U  X
# error
# 0      14377  15199  14985  2
# 1       1077   1094   1577  0
# 2        561    470    521  0
# 3        117     99    106  0
# 4         74     47     48  0
# 5         27     18     23  0
# 6          8      7      6  0
# 7         11      1     10  0
# 8          1      5      2  0
# 9          1      2      0  0
# 10         1      1      1  0
# 11         2      2      0  0
# 12         1      1      0  0
# 14         1      0      0  0
# 17         0      1      0  0
# 22         0      0      1  0

# %%
crosstab_result.plot(kind="bar", stacked=True);
